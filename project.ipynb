# %%
from dputils.scrape import Scraper,Tag

# %%
from datetime import datetime
current_date = datetime.strftime(datetime.now(), "%Y%m%d")
# date = '20240801'
url = f'https://www.espn.in/cricket/scores?date={current_date}'
sc1 = Scraper(url)

# %%
sc1.soup
# Out:
# <!DOCTYPE html>
#
# <html class="no-icon-fonts" lang="en">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="IE=edge,chrome=1" http-equiv="x-ua-compatible"/>
# <meta content="initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/>
# <meta content="origin-when-cross-origin" name="referrer"/>
# <meta content="noindex" name="Googlebot"/>
# <title>Live Cricket Scores - Find Latest Scores of all Matches Online | ESPN.in</title>
# <meta content="Get Latest Cricket Match Score updates only on ESPN.in. Check out 2024 Live Cricket Score of Ball by Ball &amp; full Scorecard of International &amp; Domestic Matches Online." name="description">
# <link href="/manifest.json" rel="manifest"/>
# <meta content="116656161708917" property="fb:app_id">
# <meta content="ESPN" property="og:site_name">
# <meta content="https://www.espn.com/cricket/scores" property="og:url"/>
# <meta content="Live Cricket Scores - Find Latest Scores of all Matches Online | ESPN.in" property="og:title"/>
# <meta content="Get Latest Cricket Match Score updates only on ESPN.in. Check out 2024 Live Cricket Score of Ball by Ball &amp; full Scorecard of International &amp; Domestic Matches Online." property="og:description"/>
# <meta content="" property="og:image"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="630" property="og:image:height"/>
# <meta content="website" property="og:type"/>
# <meta content="ESPN" name="twitter:site"/>
# <meta content="https://www.espn.com/cricket/scores" name="twitter:url"/>
# <meta content="Live Cricket Scores - Find Latest Scores of all Matches Online | ESPN.in" name="twitter:title"/>
# <meta content="Get Latest Cricket Match Score updates only on ESPN.in. Check out 2024 Live Cricket Score of Ball by Ball &amp; full Scorecard of International &amp; Domestic Matches Online." name="twitter:description"/>
# <meta content="" name="twitter:image"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="ESPN" name="twitter:app:name:iphone">
# <meta content="317469184" name="twitter:app:id:iphone"/>
# <meta content="ESPN" name="twitter:app:name:googleplay"/>
# <meta content="com.espn.score_center" name="twitter:app:id:googleplay"/>
# <meta content="Live Cricket Scores - Find Latest Scores of all Matches Online | ESPN.in" name="title"/>
# <meta content="article" name="medium"/>
# <meta content="noindex,nofollow" name="robots"/>
# <!-- Indicate preferred brand name for Google to display -->
# <script type="application/ld+json">
# 	{
# 		"@context": "https://schema.org",
# 		"@type":    "WebSite",
# 		"name":     "ESPN",
# 		"url":      "https://www.espn.com/"
#
# 	}
# </script>
# <link as="font" crossorigin="" href="https://a.espncdn.com/fonts/1.0.74/ESPNIcons/ESPNIcons.woff2" rel="preload" type="font/woff2"><!--
# <PageMap>
# 	<DataObject type="document">
# 		<Attribute name="title">Live Cricket Scores - Find Latest Scores of all Matches Online | ESPN.in</Attribute>
# 	</DataObject>
# 	<DataObject type="thumbnail">
# 		<Attribute name="src" value="https://a4.espncdn.com/combiner/i?img=%7B%7B%7Bimage%7D%7D%7D" />
# 		<Attribute name="width" value="1200" />
# 		<Attribute name="height" value="630" />
# 	</DataObject>
# </PageMap>
# -->
# <script src="https://dcf.espn.com/TWDC-DTCI/prod/Bootstrap.js" type="text/javascript"></script>
# <script type="text/javascript">
# ;(function(){
#
# function rc(a){for(var b=a+"=",c=document.cookie.split(";"),d=0;d<c.length;d++){for(var e=c[d];" "===e.charAt(0);)e=e.substring(1,e.length);if(0===e.indexOf(b))return e.substring(b.length,e.length)}return null}var _nr=!1,_nrCookie=rc("_nr");null!==_nrCookie?"1"===_nrCookie&&(_nr=!0):Math.floor(100*Math.random())+1===13?(_nr=!0,document.cookie="_nr=1; path=/"):(_nr=!1,document.cookie="_nr=0; path=/");_nr&&(function(){;window.NREUM||(NREUM={});NREUM.init={privacy:{cookies_enabled:true},ajax:{deny_list:["bam.nr-data.net"]}};
# ;NREUM.loader_config={accountID:"459463",trustKey:"486618",agentID:"4434370",licenseKey:"NRBR-0abaca59ac0e8679fd6",applicationID:"3785502"};
# ;NREUM.info={beacon:"bam.nr-data.net",errorBeacon:"bam.nr-data.net",licenseKey:"NRBR-0abaca59ac0e8679fd6",applicationID:"3785502",sa:1};
# ;(()=>{"use strict";var e,t,n={8768:(e,t,n)=>{n.d(t,{T:()=>r,p:()=>i});const r=/(iPad|iPhone|iPod)/g.test(navigator.userAgent),i=r&&Boolean("undefined"==typeof SharedWorker)},880:(e,t,n)=>{n.d(t,{P_:()=>f,Mt:()=>p,C5:()=>s,DL:()=>m,OP:()=>_,lF:()=>E,Yu:()=>y,Dg:()=>g,CX:()=>c,GE:()=>b,sU:()=>j});var r=n(6797),i=n(4286);const o={beacon:r.ce.beacon,errorBeacon:r.ce.errorBeacon,licenseKey:void 0,applicationID:void 0,sa:void 0,queueTime:void 0,applicationTime:void 0,ttGuid:void 0,user:void 0,account:void 0,product:void 0,extra:void 0,jsAttributes:{},userAttributes:void 0,atts:void 0,transactionName:void 0,tNamePlain:void 0},a={};function s(e){if(!e)throw new Error("All info objects require an agent identifier!");if(!a[e])throw new Error("Info for ".concat(e," was never set"));return a[e]}function c(e,t){if(!e)throw new Error("All info objects require an agent identifier!");a[e]=(0,i.D)(t,o),(0,r.Qy)(e,a[e],"info")}var u=n(2797);const d=()=>{const e={blockSelector:"[data-nr-block]",maskInputOptions:{password:!0}};return{allow_bfcache:!0,privacy:{cookies_enabled:!0},ajax:{deny_list:void 0,enabled:!0,harvestTimeSeconds:10},distributed_tracing:{enabled:void 0,exclude_newrelic_header:void 0,cors_use_newrelic_header:void 0,cors_use_tracecontext_headers:void 0,allowed_origins:void 0},session:{domain:void 0,expiresMs:u.oD,inactiveMs:u.Hb},ssl:void 0,obfuscate:void 0,jserrors:{enabled:!0,harvestTimeSeconds:10},metrics:{enabled:!0},page_action:{enabled:!0,harvestTimeSeconds:30},page_view_event:{enabled:!0},page_view_timing:{enabled:!0,harvestTimeSeconds:30,long_task:!1},session_trace:{enabled:!0,harvestTimeSeconds:10},session_replay:{enabled:!1,harvestTimeSeconds:60,sampleRate:.1,errorSampleRate:.1,maskTextSelector:"*",maskAllInputs:!0,get blockClass(){return"nr-block"},get ignoreClass(){return"nr-ignore"},get maskTextClass(){return"nr-mask"},get blockSelector(){return e.blockSelector},set blockSelector(t){e.blockSelector+=",".concat(t)},get maskInputOptions(){return e.maskInputOptions},set maskInputOptions(t){e.maskInputOptions={...t,password:!0}}},spa:{enabled:!0,harvestTimeSeconds:10}}},l={};function f(e){if(!e)throw new Error("All configuration objects require an agent identifier!");if(!l[e])throw new Error("Configuration for ".concat(e," was never set"));return l[e]}function g(e,t){if(!e)throw new Error("All configuration objects require an agent identifier!");l[e]=(0,i.D)(t,d()),(0,r.Qy)(e,l[e],"config")}function p(e,t){if(!e)throw new Error("All configuration objects require an agent identifier!");var n=f(e);if(n){for(var r=t.split("."),i=0;i<r.length-1;i++)if("object"!=typeof(n=n[r[i]]))return;n=n[r[r.length-1]]}return n}const h={accountID:void 0,trustKey:void 0,agentID:void 0,licenseKey:void 0,applicationID:void 0,xpid:void 0},v={};function m(e){if(!e)throw new Error("All loader-config objects require an agent identifier!");if(!v[e])throw new Error("LoaderConfig for ".concat(e," was never set"));return v[e]}function b(e,t){if(!e)throw new Error("All loader-config objects require an agent identifier!");v[e]=(0,i.D)(t,h),(0,r.Qy)(e,v[e],"loader_config")}const y=(0,r.mF)().o;var w=n(2374),A=n(1651);const x={buildEnv:A.Re,bytesSent:{},queryBytesSent:{},customTransaction:void 0,disabled:!1,distMethod:A.gF,isolatedBacklog:!1,loaderType:void 0,maxBytes:3e4,offset:Math.floor(w._A?.performance?.timeOrigin||w._A?.performance?.timing?.navigationStart||Date.now()),onerror:void 0,origin:""+w._A.location,ptid:void 0,releaseIds:{},session:void 0,xhrWrappable:"function"==typeof w._A.XMLHttpRequest?.prototype?.addEventListener,version:A.q4},D={};function _(e){if(!e)throw new Error("All runtime objects require an agent identifier!");if(!D[e])throw new Error("Runtime for ".concat(e," was never set"));return D[e]}function j(e,t){if(!e)throw new Error("All runtime objects require an agent identifier!");D[e]=(0,i.D)(t,x),(0,r.Qy)(e,D[e],"runtime")}function E(e){return function(e){try{const t=s(e);return!!t.licenseKey&&!!t.errorBeacon&&!!t.applicationID} ...
# })();
#
# })();
# </script><script src="https://secure.espn.com/core/format/modules/head/i18n?edition-host=espn.com&amp;lang=en®ion=in&amp;geo=in&amp;site=espn&amp;site-type=full&amp;type=ext&amp;build=0.697.6.2"></script>
# <link crossorigin="" href="https://a.espncdn.com" rel="preconnect"/>
# <link crossorigin="" href="https://cdn.registerdisney.go.com" rel="preconnect"/>
# <link crossorigin="" href="https://fan.api.espn.com" rel="preconnect"/>
# <link crossorigin="" href="https://secure.espn.com" rel="preconnect"/>
# <link color="#990000" href="https://a.espncdn.com/prod/assets/icons/E.svg" rel="mask-icon" sizes="any"/>
# <link href="https://a.espncdn.com/favicon.ico" rel="shortcut icon">
# <link href="https://a.espncdn.com/wireless/mw5/r1/images/bookmark-icons-v2/espn-icon-57x57.png" rel="apple-touch-icon">
# <link href="https://a.espncdn.com/wireless/mw5/r1/images/bookmark-icons-v2/espn-icon-57x57.png" rel="apple-touch-icon-precomposed"/>
# <link href="https://a.espncdn.com/wireless/mw5/r1/images/bookmark-icons-v2/espn-icon-60x60.png" rel="apple-touch-icon-precomposed" sizes="60x60"/>
# <link href="https://a.espncdn.com/wireless/mw5/r1/images/bookmark-icons-v2/espn-icon-72x72.png" rel="apple-touch-icon-precomposed" sizes="72x72"/>
# <link href="https://a.espncdn.com/wireless/mw5/r1/images/bookmark-icons-v2/espn-icon-76x76.png" rel="apple-touch-icon-precomposed" sizes="76x76"/>
# <link href="https://a.espncdn.com/wireless/mw5/r1/images/bookmark-icons-v2/espn-icon-114x114.png" rel="apple-touch-icon-precomposed" sizes="114x114"/>
# <link href="https://a.espncdn.com/wireless/mw5/r1/images/bookmark-icons-v2/espn-icon-120x120.png" rel="apple-touch-icon-precomposed" sizes="120x120"/>
# <link href="https://a.espncdn.com/wireless/mw5/r1/images/bookmark-icons-v2/espn-icon-144x144.png" rel="apple-touch-icon-precomposed" sizes="144x144"/>
# <link href="https://a.espncdn.com/wireless/mw5/r1/images/bookmark-icons-v2/espn-icon-152x152.png" rel="apple-touch-icon-precomposed" sizes="152x152"/>
# <link href="https://a.espncdn.com/wireless/mw5/r1/images/bookmark-icons-v2/espn-icon-180x180.png" rel="apple-touch-icon-precomposed" sizes="180x180"/>
# <link href="https://a.espncdn.com/redesign/0.697.6/css/shell-desktop.css" rel="stylesheet"><link href="https://a.espncdn.com/redesign/0.697.6/css/page.css" rel="stylesheet"/><link class="page-type-include" href="https://a.espncdn.com/redesign/0.697.6/css/score-center.css" rel="stylesheet"/>
# <script>
# 			var navigator = window.navigator || {};
#
# 			if ('serviceWorker' in navigator) {
# 				navigator.serviceWorker.register('/service-worker.js');
# 			}
# 		</script>
# <script src="https://a.espncdn.com/redesign/0.697.6/js/espn-head.js"></script>
# <script>
# 			if (espn && espn.geoRedirect){
# 				espn.geoRedirect.run();
# 			}
# 		</script>
# <script>
# 	var espn = espn || {};
# 	espn.isOneSite = false;
# 	espn.build = "0.697.6";
# 	espn.siteType = "full";
# 	espn.anonymous_favorites = "true" === "true";
# 	espn.isFantasycast = false;
#
# 	espn.absoluteNavLinks = false;
# 	espn.useEPlus = true;
# 	espn.hidePremiumBranding = true; // used in pof: hide e+ branding if non premium edition (SEWEB-22908)
# 	espn.enableObscuredAdsSkipping = false;
#
# 	espn.enableInlinePlayback = true;
# 	espn.enableInlinePPV = true;
# 	espn.dcsOverride = '';
# 	espn.cmsOverride = '';
# 	espn.load_hl_cb_script = false;
# </script>
# <script async="" src="https://a.espncdn.com/redesign/0.697.6/node_modules/espn-lazysizes/lazysizes.min.js"></script>
# <script type="text/javascript">
# 	(function () {
# 		var featureGating;
#
# 		try {
# 			featureGating = JSON.parse('{"draftArticleDeeplinks":false,"enableScoresDrawerOddsStrip":true,"playerFollowing":true,"showTaboolaSportIndex":true,"browerDeprecation":true,"useLatestPaywall":true,"disableBet365":false,"enableHuluPromo":false,"enableGameblockOddsStrip":true,"enableMagnite":true,"enableMyBetsSettingsOverlay":false,"drm":true,"enableLeaderboardWatchRow":true,"contributorFollowing":false,"enableScoreboardPromo":true,"womens-college-basketball-bracket-fc":true,"enableGameBreaksOnWebview":false,"contentReactions":true,"hudsonPlayer":true,"exploreTiles":false,"newSearchVersion":true,"enableGPLiveOdds":false,"continueWatching":true,"geoFooter":true,"enableMarketplace":true,"w2w":false,"disableAmp":true,"enableWatchHeaderVideoPromo":true,"oddsStrip":true,"deflateZips":false,"bettingOdds":true,"enableGraceHold":true,"enableHighVolumeRow":true,"hudsonPAL":true,"olyResultsGPWebview":false,"disableUSBettingAds":true,"mens-college-basketball-bracket-fc":true,"enableVisionEvents":true,"fittRoutes":["(nhl|nba-g-league|world-baseball-classic|nba-summer-league|mens-college-basketball|womens-college-basketball|caribbean-series|soccer|nfl)/schedule","(mlb|mens-college-basketball|womens-college-basketball|nba|wnba|nba-summer-league|nba-g-league|nbl|nfl|college-football|world-baseball-classic|caribbean-series|soccer|pll|nhl|college-baseball|college-softball|college-sports)/scoreboard","(mlb|nhl|nba|wnba|nfl|mens-college-basketball|womens-college-basketball|college-football|soccer)/team","(mlb|nba|wnba|nba-summer-league|nba-g-league|nbl|mens-college-basketball|womens-college-basketball|mens-olympics-basketball|womens-olympics-basketball|nfl|college-football|world-baseball-classic|caribbean-series|soccer|college-softball|college-baseball)/(match|boxscore|game|matchup|playbyplay|preview|recap|video|lineups|matchstats|commentary|report|verslag)"],"watchButtonV2":false,"fittVodPlayer":true,"oneIDV4":true,"activeSportsSiteAPI":true,"gateFavorites":true,"deferAdobePass":false,"usPrivacy":true,"enablePWA":true,"enableCarouselPromo":false,"showTaboolaArticle":false,"w2wNetworkFilters":false,"enableFlagship":false,"enableMyBetsModuleIndex":false,"startFromBeginning":true,"enableGamecastSponsoredAd":false,"maxFastcastGames":true,"enableCBHLTest":true,"enableFastcast":true,"refetchWatchSubscriptions":false,"mobilePlaylist":true,"siteBroadcast":true}');
# 		} catch (e) {}
#
# 		window.espn.featureGating = featureGating || {};
# 	})();
# </script>
# <script>
# 		window.googletag = window.googletag || {};
#
# 		(function () {
# 			espn = window.espn || {};
# 			espn.ads = espn.ads || {};
# 			espn.ads.config = {"page_url":"https://www.espn.com/cricket/scores","prebidAdConfig":{"usePrebidBids":true,"timeout":1000},"level":"espn.in/cricket/scoreboard","delayInPageAdSlots":true,"incontentPositions":{"defaults":{"favorites":4,"news":4,"now":4},"index":{"top":{},"nfl":{}}},"showEspnPlusAds":false,"network":"21783347309","refreshOnBreakpointChange":true,"sizes":{"overlay":{"mappings":[{"viewport":[0,0],"slot":[[0,0]]}],"defaultSize":[0,0]},"wallpaper":{"mappings":[{"viewport":[1280,0],"slot":[[1680,1050]]},{"viewport":[1024,0],"slot":[[1280,455]]},{"viewport":[0,0],"slot":[]}],"defaultSize":[1280,455]},"banner-scoreboard":{"excludedSize":["970,250"],"mappings":[{"viewport":[1280,0],"slot":[[1280,100],[728,90]]},{"viewport":[1024,0],"slot":[[970,66],[728,90]]},{"viewport":[768,0],"slot":[[728,90]]},{"viewport":[320,0],"slot":[[320,50]]},{"viewport":[0,0],"slot":[[240,38]]}],"defaultSize":[970,66],"includedCountries":["us","in"],"pbjs":{"s":[[320,50]],"xl":[[728,90]],"l":[[728,90]],"m":[[728,90]]}},"incontent2":{"mappings":[{"viewport":[0,0],"slot":[[300,250]]}],"defaultSize":[300,250]},"banner":{"mappings":[{"viewport":[1280,0],"slot":[[1280,100],[970,250],[728,90]]},{"viewport":[1024,0],"slot":[[970,66],[970,250],[728,90]]},{"viewport":[768,0],"slot":[[728,90]]},{"viewport":[320,0],"slot":[[320,50]]},{"viewport":[0,0],"slot":[[240,38]]}],"defaultSize":[970,66],"pbjs":{"s":[[320,50]],"xl":[[970,250],[728,90]],"l":[[970,250],[728,90]],"m":[[728,90]]}},"exclusions":{"mappings":[{"viewport":[0,0],"slot":[[1,2]]}],"defaultSize":[1,2]},"banner-index":{"excludedSize":["728,90"],"mappings":[{"viewport":[1280,0],"slot":[[1280,100],[970,250]]},{"viewport":[1024,0],"slot":[[970,66],[970,250]]},{"viewport":[768,0],"slot":[[728,90]]},{"viewport":[320,0],"slot":[[320,50]]},{"viewport":[0,0],"slot":[[240,38]]}],"defaultSize":[970,66],"excludedProfile":["xl"],"includedCountries":["us","in"],"pbjs":{"s":[[320,50]],"xl":[[970,250]],"l":[[970,250]],"m":[[728,90]]}},"presby":{"mappings":[{"viewport":[0,0],"slot":[[112,62]]}],"defaultSize":[112,62]},"native":{"mappings":[{"viewport":[0,0],"slot":["fluid"]}],"defaultSize":"fluid"},"incontentstrip":{"mappings":[{"viewport":[1024,0],"slot":[298,50]},{"viewport":[0,0],"slot":[]}],"defaultSize":[298,50]},"promobox":{"mappings":[{"viewport":[1024,0],"slot":[[300,100]]},{"viewport":[0,0],"slot":[]}],"defaultSize":[300,100]},"instream":{"mappings":[{"viewport":[0,0],"slot":[[1,3]]}],"defaultSize":[1,3]},"incontentstrip2":{"mappings":[{"viewport":[320,0],"slot":[[298,50]]}],"defaultSize":[298,50]},"incontent":{"mappings":[{"viewport":[1024,0],"slot":[[300,250],[300,600]]}],"defaultSize":[300,250]},"midpage":{"mappings":[{"viewport":[1280,0],"slot":[[700,400]]},{"viewport":[1024,0],"slot":[[440,330]]},{"viewport":[768,0],"slot":[[320,250]]},{"viewport":[0,0],"slot":[[320,250]]}],"defaultSize":[320,250]}},"refreshRate":120,"supportDynamicPageLoad":true,"selector":".ad-slot","disabled":"false","override":{"banner":{"preview":"banner-scoreboard","game":"banner-scoreboard","fightcenter":"banner-scoreboard","match":"banner-scoreboard","index":"banner-index","scoreboard":"banner-scoreboard","conversation":"banner-scoreboard","lineups":"banner-scoreboard"}},"breakpoints":{"s":[0,767],"xl":[1280],"l":[1024,1279],"m":[768,1023]},"dynamicKeyValues":{"profile":{"key":"prof"}},"id":15039572,"kvps":[{"name":"ed","value":"in"},{"name":"ajx_url","value":"https://www.espn.com/cricket/scores"},{"name":"sp","value":"cricket"},{"name":"pgtyp","value":"scoreboard"},{"name":"darkmode","value":"false"}],"base":"espn.in"};
# 			googletag.cmd = googletag.cmd || [];
#
# 			var espnAdsConfig = espn.ads.config;
# 			espn.ads.loadGPT = function () {
# 				var gads = document.createElement('script');
# 				gads.async = true;
# 				gads.type = 'text/javascript';
# 				gads.src = espnAdsConfig.network ? 'https://www.googletagservices.com/tag/js/gpt.js'+'?network-code='+ espnAdsConfig.network : 'https://www.googletagservices.com/tag/js/gpt.js';
# 				var node = document.getElementsByTagName('script')[0];
# 				node.parentNode.insertBefore(gads, node);
# 				delete espn.ads.loadGPT;
# 			}
#
# 			if (espn.siteType === 'data-lite') {
# 				/**
# 				 * Load ad library after our deferred files. Event subscription must
# 				 * occur on window.load to ensure pub/sub availability.
# 				 */
#
# 				// Ad calls will be made when ad library inits (after window.load).
# 				var liteAdLoadConfigs = {
# 					desktop: 'init',
# 					mobile: 'init',
# 					tablet: 'init'
# 				};
#
# 				espnAdsConfig.load = espnAdsConfig.load || {};
# 				espnAdsConfig.load.defaults = liteAdLoadConfigs
# 				espnAdsConfig.load.frontpage = liteAdLoadConfigs;
# 				espnAdsConfig.load.index = liteAdLoadConfigs;
# 				espnAdsConfig.load.story = liteAdLoadConfigs;
# 			} else {
# 				espn.ads.loadGPT();
# 			}
#
#
#
#     // Load prebid.js for AppNexus
#     (function() {
#         var d   = document,
#             pbs = d.createElement('script'),
#             target;
#
#         window.espn = window.espn || {};
#         espn.ads = espn.ads || {};
#         espn.ads.isMagnite = false;
#
#         pbs.type = 'text/javascript';
#         pbs.src = 'https://a.espncdn.com/prod/scripts/prebid8.26.0.js';
#         target = document.getElementsByTagName('head')[0];
#         target.insertBefore(pbs, target.firstChild);
#     })();
#
#
#
# 			espn.ads.configPre = JSON.parse(JSON.stringify(espnAdsConfig));
# 		})();
# 	</script>
# <script type="text/javascript">
# 	(function () {
# 		var exitModal;
# 		try {
# 			exitModal = JSON.parse('null');
# 		} catch (e) {}
# 		window.espn.exitModalConfig = exitModal || [];
# 	})();
# </script>
# <!-- test & target - mbox.js -->
# <script src="https://a.espncdn.com/prod/scripts/analytics/ESPN_at_v2.rs.min.js" type="text/javascript"></script>
# <script>
# 	// Picture element HTML shim|v it for old IE (pairs with Picturefill.js)
# 	document.createElement("picture");
# </script>
# </link></link></link></link></meta></meta></meta></meta></head>
# <body class="scoreboard desktop prod" data-app="" data-appearance="light" data-customstylesheet="null" data-edition="en-in" data-lang="en" data-pagetype="scoreboard" data-site="espn" data-sport="cricket">
# <div class="ad-slot ad-slot-exclusions" data-category-exclusion="true" data-slot-kvps="pos=exclusions" data-slot-type="exclusions"></div><div class="ad-slot ad-slot-overlay" data-out-of-page="true" data-slot-kvps="pos=outofpage" data-slot-type="overlay"></div>
# <!-- abtest data object global -->
# <script type="text/javascript">
# 			var abtestData = {};
#
# 		</script>
# <div id="fb-root"></div>
# <div class="interior secondary" data-behavior="global_nav_condensed global_nav_full" id="global-viewport">
# <nav data-loadtype="server" id="global-nav-mobile"></nav>
# <div class="menu-overlay-primary"></div>
# <div class="hidden-print" id="header-wrapper">
# <section class="hide-fullbtn" id="global-scoreboard" role="region">
# <button class="scoreboard-hidden-skip" data-behavior="scoreboard_skipnav" data-skip="content">
#         Skip to main content
#     </button>
# <button class="scoreboard-hidden-skip" data-behavior="scoreboard_skipnav" data-skip="nav">
#         Skip to navigation
#     </button>
# <div class="wrap">
# <div class="scoreboard-content">
# <div class="scoreboard-dropdown-wrapper scoreboard-menu">
# <!-- mobile dropdown -->
# <div class="league-nav-wrapper league-nav-mobile mobile-dropdown">
# <span class="mobile-arrow"></span>
# <select id="league-nav"></select>
# </div>
# <!-- desktop dropdown -->
# <div class="dropdown-wrapper league-nav-desktop desktop-dropdown" data-behavior="button_dropdown">
# <button class="button button-filter sm dropdown-toggle current-league-name" type="button"></button>
# <ul class="dropdown-menu league-nav med"></ul>
# </div>
# </div>
# <div class="scoreboard-dropdown-wrapper conference-menu">
# <!-- mobile dropdown -->
# <div class="conference-nav-wrapper mobile-dropdown">
# <span class="mobile-arrow"></span>
# <select id="conference-nav"></select>
# </div>
# <!-- desktop dropdown -->
# <div class="dropdown-wrapper desktop-dropdown" data-behavior="button_dropdown">
# <button class="button button-filter med dropdown-toggle current-conference-name" type="button"></button>
# <ul class="dropdown-menu conference-nav med"></ul>
# </div>
# </div>
# <div class="scoreboard-dropdown-wrapper scores-date-pick">
# <div class="dropdown-wrapper" data-behavior="button_dropdown">
# <button class="button button-filter dropdown-toggle sm selected-date" type="button"></button>
# <ul class="dropdown-menu date-nav med"></ul>
# </div>
# </div>
# <div class="scoreboard-dropdown-wrapper secondary-nav-container hidden"></div>
# <div class="scores-prev controls inactive">&lt;</div>
# <div class="view-full" id="fullbtn"></div>
# <div class="scores-next controls">&gt;</div>
# <div class="scores-carousel">
# <ul id="leagues"></ul>
# </div>
# </div>
# </div>
# </section>
# <header class="espnin-en user-account-management has-search" id="global-header">
# <div class="menu-overlay-secondary"></div>
# <div class="container">
# <a data-route="false" href="#" id="global-nav-mobile-trigger"><span>Menu</span></a><h2 class="logo-header"><a href="/" name="&amp;lpos=sitenavdefault&amp;lid=sitenav_main-logo">ESPN</a></h2><ul class="tools"><li class="search">
# <a aria-label="Open Search" class="icon-font-after icon-search-solid-after" href="#" id="global-search-trigger" role="button" tabindex="0"></a>
# <div class="global-search" id="global-search">
# <div class="global-search-input-wrapper">
# <input aria-label="Search" class="search-box" id="global-search-input" placeholder="Search Sports, Teams or Players..." tabindex="-1" type="text"/><input class="btn-search" tabindex="-1" type="submit"/>
# </div>
# </div></li><li class="user" data-behavior="favorites_mgmt"></li><li id="scores-link"><a data-route="false" href="#" id="global-scoreboard-trigger">scores</a></li></ul>
# <div class="alert-container tooltip" data-behavior="edition_alert">
# <div class="grid-row">
# <div class="alert-column">
# <div class="icon-font-before icon-alert01-solid-before">
# <p>Welcome to ESPN India Edition</p>
# <a class="icon-font-after icon-close-solid-after" href="#"></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <nav data-loadtype="server" id="global-nav">
# <ul itemscope="" itemtype="http://www.schema.org/SiteNavigationElement">
# <li itemprop="name"><a href="/olympics/" itemprop="url">Olympic Sports</a></li><li itemprop="name"><a href="/football/" itemprop="url">Football</a></li><li itemprop="name"><a href="/cricket/" itemprop="url">Cricket</a></li><li itemprop="name"><a href="/f1/" itemprop="url">F1</a></li><li itemprop="name"><a href="/nba/" itemprop="url">NBA</a></li><li itemprop="name"><a href="/badminton/" itemprop="url">Badminton</a></li><li itemprop="name"><a href="/field-hockey/" itemprop="url">Hockey</a></li><li itemprop="name"><a href="/football/league/_/name/ind.1" itemprop="url">ISL</a></li><li itemprop="name"><a href="/tennis/" itemprop="url">Tennis</a></li><li itemprop="name"><a href="#" itemprop="url">…</a><div><ul class="split"><li itemprop="name"><a href="/wrestling/" itemprop="url">Wrestling</a></li><li itemprop="name"><a href="/rugby/" itemprop="url">Rugby</a></li><li itemprop="name"><a href="https://www.espn.in/football/league/_/name/fifa.world" itemprop="url">FIFA World Cup</a></li><li itemprop="name"><a href="/mma/" itemprop="url">MMA</a></li><li itemprop="name"><a href="/boxing/" itemprop="url">Boxing</a></li><li itemprop="name"><a href="/nfl/" itemprop="url">NFL</a></li><li itemprop="name"><a href="/nhl/" itemprop="url">NHL</a></li><li itemprop="name"><a href="/shooting/" itemprop="url">Shooting</a></li><li itemprop="name"><a href="/athletics/" itemprop="url">Athletics</a></li><li itemprop="name"><a href="/golf/" itemprop="url">Golf</a></li><li itemprop="name"><a href="/kabaddi/" itemprop="url">Kabaddi</a></li><li itemprop="name"><a href="/wwe/" itemprop="url">WWE</a></li><li itemprop="name"><a href="/mlb/" itemprop="url">MLB</a></li><li itemprop="name"><a href="/chess/" itemprop="url">Chess</a></li><li itemprop="name"><a href="/motogp/" itemprop="url">Moto GP</a></li><li itemprop="name"><a href="/specialolympics/" itemprop="url">Special Olympics</a></li><li itemprop="name"><a href="/mens-college-basketball/" itemprop="url">NCAAM</a></li><li itemprop="name"><a href="/racing/nascar/" itemprop="url">NASCAR</a></li><li itemprop="name"><a href="/college-football/" itemprop="url">NCAAF</a></li><li itemprop="name"><a href="/womens-basketball/" itemprop="url">NCAAW</a></li><li itemprop="name"><a href="/asian-games/" itemprop="url">Asian Games</a></li><li itemprop="name"><a href="/commonwealth-games/" itemprop="url">Commonwealth Games</a></li><li itemprop="name"><a href="http://xgames.com/" itemprop="url">X Games</a></li></ul></div></li><li class="pillar more-espn"><a href="#">More ESPN</a></li><li class="pillar watch"><a href="/watch/">Watch</a></li></ul>
# </nav>
# <nav data-loadtype="server" id="global-nav-secondary">
# <div class="global-nav-container">
# <script type="text/javascript">
# 		var espn = espn || {};
# 		espn.nav = espn.nav || {};
# 		espn.nav.navId = 14327888;
# 		espn.nav.isFallback = false;
#
#
#
#
#
#
# 	</script>
# </div>
# </nav>
# </header>
# </div>
# <section id="pane-main"><div id="reduxion"><div data-react-checksum="2078958471" data-reactid="1" data-reactroot=""><div data-id="scoreboard" data-reactid="2" id="custom-nav"></div><div class="ad-banner-wrapper" data-reactid="3"><div class="react-ad react-ad ad-slot-banner ad-wrapper ad-slot" data-kvpos="" data-reactid="4" data-slot-kvps="pos=banner" data-slot-type="banner" id="banner"></div></div><section data-reactid="5" id="main-container"><div class="layout-bc scoreCenter" data-reactid="6"><div data-reactid="7"></div><div class="col-b" data-reactid="8"><header class="scoreCollection__PageHeader" data-reactid="9" style="overflow:visible;"><div class="scoreCollection__headerTop" data-reactid="10"><h1 data-reactid="11">Live Cricket Scores</h1></div><div class="DatePicker DatePicker--cricket" data-reactid="12"><div class="DateCarousel" data-reactid="13" style="overflow:hidden;-ms-overflow-style:none;"><button class="carousel__arrow carousel__arrow--left" data-reactid="14"></button><ul class="DateCarousel__list" data-reactid="15" style="width:720px;left:-160px;overflow-y:initial;"><li class="DateCarousel__list__item has-event" data-reactid="16"><div class="DateCarousel__day" data-reactid="17" style="font-size:inherit;"><span class="DateCarousel__dayNum" data-reactid="18"><span data-reactid="19">19 Aug</span></span><span class="DateCarousel__dayName" data-reactid="20" style="color:inherit;">Mon</span></div></li><li class="DateCarousel__list__item has-event" data-reactid="21"><div class="DateCarousel__day" data-reactid="22" style="font-size:inherit;"><span class="DateCarousel__dayNum" data-reactid="23"><span data-reactid="24">20 Aug</span></span><span class="DateCarousel__dayName" data-reactid="25" style="color:inherit;">Tue</span></div></li><li class="DateCarousel__list__item has-event" data-reactid="26"><div class="DateCarousel__day" data-reactid="27" style="font-size:inherit;"><span class="DateCarousel__dayNum" data-reactid="28"><span data-reactid="29">21 Aug</span></span><span class="DateCarousel__dayName" data-reactid="30" style="color:inherit;">Wed</span></div></li><li class="DateCarousel__list__item is-active" data-reactid="31"><div class="DateCarousel__day" data-reactid="32" style="font-size:inherit;"><span class="DateCarousel__dayNum" data-reactid="33"><span data-reactid="34">Now</span></span></div></li><li class="DateCarousel__list__item has-event" data-reactid="35"><div class="DateCarousel__day" data-reactid="36" style="font-size:inherit;"><span class="DateCarousel__dayNum" data-reactid="37"><span data-reactid="38">23 Aug</span></span><span class="DateCarousel__dayName" data-reactid="39" style="color:inherit;">Fri</span></div></li><li class="DateCarousel__list__item has-event" data-reactid="40"><div class="DateCarousel__day" data-reactid="41" style="font-size:inherit;"><span class="DateCarousel__dayNum" data-reactid="42"><span data-reactid="43">24 Aug</span></span><span class="DateCarousel__dayName" data-reactid="44" style="color:inherit;">Sat</span></div></li><li class="DateCarousel__list__item has-event" data-reactid="45"><div class="DateCarousel__day" data-reactid="46" style="font-size:inherit;"><span class="DateCarousel__dayNum" data-reactid="47"><span data-reactid="48">25 Aug</span></span><span class="DateCarousel__dayName" data-reactid="49" style="color:inherit;">Sun</span></div></li><li class="DateCarousel__list__item has-event" data-reactid="50"><div class="DateCarousel__day" data-reactid="51" style="font-size:inherit;"><span class="DateCarousel__dayNum" data-reactid="52"><span data-reactid="53">26 Aug</span></span><span class="DateCarousel__dayName" data-reactid="54" style="color:inherit;">Mon</span></div></li><li class="DateCarousel__list__item has-event" data-reactid="55"><div class="DateCarousel__day" data-reactid="56" style="font-size:inherit;"><span class="DateCarousel__dayNum" data-reactid="57"><span data-reactid="58">27 Aug</span></span><span class="DateCarousel__dayName" data-reactid="59" style="color: ...
# <!-- Redux app -->
# <script type="text/javascript">
#
#           window.__INITIAL_STATE__ = {"news":{},"editorial":{"editorialItems":[],"heading":"Editorial"},"leagues":{},"scoreboard":{"loading":false,"topEventLeagues":[{"name":"Top Events","text":"Top Events","abbreviation":"Top Events","id":"","events":[],"seriesHome":"","isTopEvents":true}],"favTeams":[],"favLeagues":[],"leagues":[{"name":"Women's Caribbean Premier League","text":"Women's Caribbean Premier League","abbreviation":"WCPL","calendar":["2024-08-21T00:00:00Z","2024-08-22T00:00:00Z"],"slug":"womens-caribbean-premier-leag","id":"20898","events":[{"gameId":"1443199","gameDate":"August 21st, 2024","date":"2024-08-21T23:00Z","teams":{"home":{"name":"Barbados Royals Women","id":"1323140","abbr":"BAR-W","logo":"https://a1.espncdn.com/combiner/i?img=/i/teamlogos/cricket/500/1323140.png&h=35&w=35","href":"https://www.espn.in/cricket/team/_/id/1323140/barbados-royals-women","score":"119/9 (19.5/20 ov, target 119)","runDetails":"119/9 ","overDetails":"(19.5/20 ov, target 119)","scoreMarkup":"119/9 <div class='sm'>(19.5/20 ov)</div>","scoreMarkupSpan":"119/9 <span class='cscore_overs'>(19.5/20 ov, target 119)</span>","links":[{"rel":["clubhouse","desktop"],"href":"https://www.espn.in/cricket/team/_/id/1323140/barbados-royals-women","text":"Clubhouse","isExternal":false,"isPremium":false}],"winner":"true","record":"Form: undefined","order":2,"countryCode":"www"},"away":{"name":"Guyana Amazon Warriors Women","id":"1323141","abbr":"GAW-W","logo":"https://a1.espncdn.com/combiner/i?img=/i/teamlogos/cricket/500/1323141.png&h=35&w=35","href":"https://www.espn.in/cricket/team/_/id/1323141/guyana-amazon-warriors-women","score":"118/9","runDetails":"118/9","overDetails":"","scoreMarkup":"118/9","scoreMarkupSpan":"118/9","links":[{"rel":["clubhouse","desktop"],"href":"https://www.espn.in/cricket/team/_/id/1323141/guyana-amazon-warriors-women","text":"Clubhouse","isExternal":false,"isPremium":false}],"winner":"false","record":"Form: undefined","order":1,"countryCode":"www"},"teamsOrder":["away","home"],"teamGeo":["WWW","WWW"],"gameInfo":"Barbados Royals Women_vs_Guyana Amazon Warriors Women"},"gameState":"final","statusText":"RESULT","winnerClass":"home","links":[{"href":"/cricket/series/20898/scorecard/1443199/barbados-royals-women-vs-guyana-amazon-warriors-women-1st-match-womens-caribbean-premier-league-2024","text":"Scorecard","rel":["event","boxscore","scorecard","match","desktop"],"trackingName":"&lpos=cricket:scoreboard:scorecard","react":true},{"href":"/cricket/series/20898/game/1443199/barbados-royals-women-vs-guyana-amazon-warriors-women-1st-match-womens-caribbean-premier-league-2024","text":"Summary","rel":["event","boxscore","match","live","summary","desktop"],"trackingName":"&lpos=cricket:scoreboard:match","react":true},{"href":"/cricket/series/_/id/20898/season/2024/womens-caribbean-premier-league","text":"Series Home","rel":["event","league","serieshome","desktop"],"trackingName":"&lpos=cricket:scoreboard:serieshome"}],"gameUrl":"/cricket/series/20898/game/1443199/barbados-royals-women-vs-guyana-amazon-warriors-women-1st-match-womens-caribbean-premier-league-2024","note":"Royals [W] won by 1 wkt (1b rem)","info":"1st Match,  (N) at Tarouba, Aug 21 2024","favInfo":"1st Match (N), Women's Caribbean Premier League at Tarouba, Aug 21 2024","eventSummary":{"home":{},"away":{}},"eventClock":"0'","odds":{},"isTopEvent":false,"timeValid":true},{"gameId":"1443200","gameDate":"August 22nd, 2024","date":"2024-08-22T23:00Z","teams":{"home":{"name":"Trinbago Knight Riders Women","id":"1323139","abbr":"TKR-W","logo":"https://a1.espncdn.com/combiner/i?img=/i/teamlogos/cricket/500/1323139.png&h=35&w=35","href":"https://www.espn.in/cricket/team/_/id/1323139/trinbago-knight-riders-women","score":"","runDetails":"","overDetails":"","scoreMarkup":"","scoreMarkupSpan":"","links":[{"rel":["clubhouse","desktop"],"href":"https://www.espn.in/cricket/team/_/id/1323139/trinbago-knight-riders-women","text":"Clubhouse","isExternal":false,"isPremium":fals ...
#           window.espn = window.espn || {};
#           window.espn.reduxion = {};
#           window.espn.reduxion.apiHost = {"sCoreTcClient":"www.espn.com/core","sCoreTcServer":"www.espn.com/core","sCoreQahost":"www.espnqa.com/core","client":"site.web.api.espn.com","server":"site.web.api.espn.com","client_qa":"site.web.api.espnqa.com","server_qa":"site.web.api.espnqa.com","client_sb":"site.web.api.espnsb.com","server_sb":"site.web.api.espnsb.com","client_v1":"api-app.espn.com","server_v1":"api-app.espn.com","now_client":"now.core.api.espn.com","now_server":"now.core.api.espn.com"};
#           window.__CDN_PATH__ = '//cdn1.espn.net/sCoreNode/5489c2b031db-19-09-2325/client';
#
# </script>
# <script src="//cdn1.espn.net/sCoreNode/5489c2b031db-19-09-2325/client/reduxion.bundle.js"></script>
# <!-- Redux app -->
# </section>
#
# </div>
# <script>
# 	var espn_ui = window.espn_ui || {};
# 	espn_ui.staticRef = "https://a.espncdn.com/redesign/0.697.6";
# 	espn_ui.imgRef = "https://a.espncdn.com/redesign/assets/img/";
# 	espn_ui.insertRef = "https://a.espncdn.com";
# 	espn_ui.deviceType = "desktop";
# 	espn_ui.pageShell = true;
# 	espn_ui.pubKey = null;
# 	espn.api = {};
# 	espn_ui.webview = false;
# 	espn_ui.useNativeBridge = false;
# 	espn_ui.onefeed = false;
# 	espn_ui.abtests = {"kahuna":40,"kplus":41,"kminus":42,"auddev1":45,"auddev2":46,"auddevcontrol":47,"headlinetester":48,"control":52,"carousel":53,"followcarouselcontrol":54,"followcarouseltest":55,"followcarouselenabled":56,"adtestcontrol":57,"favesTest":58,"tierTest":59,"relatedVideosCDP":60,"relatedVideosATG":61,"stayOnHttps":62,"hideminifeed":63,"epluslogo":64,"everscroll":65,"taboola-5":70,"taboola-10":71,"taboola-15":72,"taboola-1x6mobile":73,"taboola-1x8mobile":74,"eplusmodulelinks":75,"eplusmoduledescriptor":76,"controlvariant":77,"personalizedvariant":78,"plethoravariant1":79,"plethoravariant2":80,"plethoravariant3":81,"plethoracontrol":82,"controllegalfooter":83,"whitelegalfooter":84,"graylegalfooter":85,"paragraphpaywalltext0":86,"paragraphpaywalltext1":87,"paywalltextcontrol":88,"paragraphpaywalltext3":89,"paywalltextoverride":90,"articleinlinefooter":91,"articlebottompopupfooter":92,"plethoravariant4":93,"plethoravariant5":94,"plethoravariant6":95,"plethoravariant7":96,"plethoracontrol2":97,"articleadslot":98,"articleadslotcontrol":99};
# 	espn_ui.isCurated = false;
# 	espn_ui.error = false;
# 	espn_ui.dcf   = false;
#
# 	function setIsCurated () {
# 		$('#news-feed').attr('data-curated', espn_ui.isCurated);
# 		$(document).trigger('checkIfShouldAutoUpdate');
# 		espn_ui.checkIfShouldAutoUpdate = true;
# 	}
#
# 	//this is also set on ajax page loads in js/helpers/page.js
# 	if (document.readyState == 'complete') {
# 		setIsCurated();
# 	} else {
# 		window.onload = setIsCurated;
# 	}
#
# 	var tcStatus = {"tcTwoLocked":false,"fantasyLocked":false,"tcLocked":false,"tcwLocked":false,"tcTwoOn":false,"tcwOn":false,"fantasyOn":true,"tcOn":false,"tcwTwoOn":false,"tcwTwoLocked":false};
#
# </script>
# <script src="https://a.espncdn.com/redesign/0.697.6/js/espn-critical.js"></script>
# <script type="text/javascript">
# 	var espn = espn || {};
#
# 	// Build skeleton for namespace.
# 	espn.scoreboard = {
# 		topics: {
# 			scoreboard: '',
# 			scoreboxes: []
# 		},
# 		models: {},
# 		views: {},
# 		collections: {},
# 		timezoneOffset: 0,
# 		favorites: {},
# 		editData: {},
# 		settings: {
# 			useStatic: false,
# 			version: 2,
# 			topEventsId: 14327607,
# 			topSoccerId: 15590105
#
#
#
#
#
# 		}
# 	};
#
#
#
# </script>
# <script type="text/javascript">
# 		jQuery.subscribe('espn.defer.end', function () {
# 			espn.scoreboard.init(null, {
# 				params :
# 					{"type":"scoreboard","sportSection":"cricket","indexTopics":{"supportedPubKeys":{"espn-es-co-soccer-index":true,"espnin-en-soccer-index":true,"espn-es-ar-frontpage-index":true,"espn-es-cl-soccer-index":true,"espnin-en-cricket-index":true,"espnuk-en-rugby-index":true,"espnau-en-frontpage-index":true,"espnuk-en-tennis-index":true,"espn-es-cl-frontpage-index":true,"espnuk-en-frontpage-index":true,"espn-en-ncaa-index":true,"espnin-en-frontpage-index":true,"espn-en-tennis-index":true,"espn-es-ar-rpm-index":true,"espn-es-mx-soccer-index":true,"espn-en-womenbb-index":true,"espnuk-en-cricket-index":true,"espnin-en-tennis-index":true,"espn-es-ve-soccer-index":true,"espn-es-ar-soccer-index":true,"espn-es-us-frontpage-index":true,"espn-es-ar-tennis-index":true,"espn-es-co-frontpage-index":true,"espn-es-us-other-sports-index":true,"espn-es-us-soccer-index":true,"espnau-en-rugby-index":true,"espnza-en-frontpage-index":true,"espnuk-en-soccer-index":true,"espn-en-frontpage-index":true,"17784479":true,"espn-es-ve-frontpage-index":true,"espn-es-mx-frontpage-index":true,"espn-es-ar-rugby-index":true,"espnza-en-soccer-index":true,"espn-en-rpm-index":true,"espn-en-frontpage-grant-test-index":true}}}
# 			});
# 		});
# 	</script>
# <script>
# 	(function() {
# 		function loadDefer() {
# 			var deferScripts = [
# 				'https://a.espncdn.com/redesign/0.697.6/js/espn-defer.js',
# 				'https://a.espncdn.com/redesign/0.697.6/js/espn-defer-low.js'
# 			];
#
# 			$.when(deferScripts.map(function (script) {
# 				var deferred = $.Deferred();
# 				$.getScriptCache(script, deferred.resolve);
# 				return deferred;
# 			})).done(function () {
# 				if(espn.siteType === 'data-lite' && typeof espn.ads.loadGPT === 'function') {
# 					espn.ads.loadGPT();
# 				}
# 			});
# 		}
#
# 		if(window.espn.loadType === "loadEnd" && espn_ui.deviceType !== 'desktop') {
# 			var race = [];
# 			$.when(function () {
# 				var deferred = $.Deferred();
# 				$(window).load(deferred.resolve);
# 				if(espn.siteType !== 'data-lite') {
# 					setTimeout( deferred.resolve, 5000 );
# 				}
# 				return deferred;
# 			}()).then(loadDefer)
#
# 		}else{
# 			loadDefer();
# 		}
#
# 	})();
# 	</script>
# <script>espn_ui.Helpers.translate.init();</script>
# <script type="text/javascript">
# 				var data = {"omniture":{"espn3ContentType":"scoreboard:espnin:cricket","countryRegion":"en-in","hier1":"cricket:scoreboard","section":"cricket","pageName":"cricket:scoreboard","sections":"cricket:scoreboard","site":"espnin","premium":"premium-no","appearance":"light","convrSport":"cricket","pageURL":"www.espn.com/","lang":"en_in","prop46":"name=sCoreTc, type=0","contentType":"scoreboard","sport":"cricket","account":"wdgespcom","siteType":"full","prop58":"isIndex=false"},"chartbeat":{"loadPubJS":false,"path":"/cricket/scores","zone":"www.espn.com.in.cricket","domain":"www.espn.com","loadVidJS":true,"title":"Live Cricket Scores - Find Latest Scores of all Matches Online | ESPN.in","sections":"cricket","authors":"scoreboard"},"qualtrics":false,"nielsen":{"espnuk":{"apid":"P07264C85-15CD-4A80-8E56-B5BFA6D93296","vc":"b01"},"espnau":{"apid":"P07264C85-15CD-4A80-8E56-B5BFA6D93296","vc":"b01"},"espn":{"apid":"P07264C85-15CD-4A80-8E56-B5BFA6D93296","vc":"b01"},"fantasy":{"apid":"P302B69D5-F1DD-4E7A-BF8D-3E60F0EB5E5A","vc":"c07"},"espndeportes":{"apid":"P890E2723-EDBC-4CCE-96BA-F35EA3E50650","vc":"c02"},"espnfc":{"apid":"PE6995AAE-0C49-4372-B5E7-54C61BFE2AA5","vc":"c03"},"espnww":{"apid":"P07264C85-15CD-4A80-8E56-B5BFA6D93296","vc":"b01"},"general":{"ci":"us-600140","assetid":"N/A","segB":"N/A","sfcode":"dcr","segA":"N/A","section":"N/A","segC":"N/A","apn":"espnCOM"},"espnza":{"apid":"P07264C85-15CD-4A80-8E56-B5BFA6D93296","vc":"b01"},"espnin":{"apid":"P07264C85-15CD-4A80-8E56-B5BFA6D93296","vc":"b01"},"watchespn":{"apid":"P07264C85-15CD-4A80-8E56-B5BFA6D93296","vc":"b01"},"cricinfo":{"apid":"PED8CDAC2-F114-41BE-8B98-AFA06FAEA06E","vc":"c04"},"espnbr":{"apid":"P07264C85-15CD-4A80-8E56-B5BFA6D93296","vc":"b01"}},"ABTest":{"environment":"prod","tScript":"https://a.espncdn.com/prod/scripts/analytics/ESPN_at_v2.rs.min.js","oScript":"https://cdn.optimizely.com/js/310987714.js","targetURLs":[{"regexp":"(/)","site":"espn.co.uk","flag":true},{"regexp":"(/.*)","site":"www.espn.com","flag":true}],"domain":"www.espn.com","host":"espn.com","raw":"{\"fastcast\":{\"placements\":{\"/nba/index\":\"true\",\"^/.+$\":\"false\",\"/ncf/index\":\"true\"},\"enabled\":false,\"script\":\"https://a.espncdn.com/combiner/c?js=analytics/espn.fastcastTracking.4.js\"},\"optimizely\":{\"oldscript\":\"https://a.espncdn.com/sports/optimizely.js\",\"placements\":[],\"enabled\":false,\"script\":\"https://cdn.optimizely.com/js/310987714.js\"},\"target\":{\"placements\":[{\"regexp\":\"(/)\",\"site\":\"espn.co.uk\",\"flag\":true},{\"regexp\":\"(/.*)\",\"site\":\"www.espn.com\",\"flag\":true}],\"enabled\":true,\"script\":\"https://a.espncdn.com/prod/scripts/analytics/ESPN_at_v2.rs.min.js\"}}","optimizely":false,"isTargeted":true,"target":true,"optimizelyURLs":[]},"metrics":{"page_url":"/","site":"espnin","content_type":"scoreboard","page_infrastructure":"sCoreNode","page_type":"scoreboard","page_name":"espnin:cricket:scoreboard","section":"cricket","sport":"cricket"},"isFeaturePhone":false,"device":"desktop","cto":false};
# 				var espn = espn || {};
# 				espn.track = espn.track || {};
# 				espn.track.data = data;
# 			</script>
# <!-- SiteCatalyst code version: AppMeasurement 1.0 Copyright 1996-2013 Adobe, Inc. -->
# <script type="text/javascript">
#
#
# 	if (typeof s_omni === 'undefined') {
# 		jQuery(function($){
# 			$.getScriptCache("https://a.espncdn.com/redesign/0.697.6/js/espn-analytics.js", 				function() {					$.publish('analytics.loaded', [ {"omniture":{"espn3ContentType":"scoreboard:espnin:cricket","countryRegion":"en-in","hier1":"cricket:scoreboard","section":"cricket","pageName":"cricket:scoreboard","sections":"cricket:scoreboard","site":"espnin","premium":"premium-no","appearance":"light","convrSport":"cricket","pageURL":"www.espn.com/","lang":"en_in","prop46":"name=sCoreTc, type=0","contentType":"scoreboard","sport":"cricket","account":"wdgespcom","siteType":"full","prop58":"isIndex=false"},"chartbeat":{"loadPubJS":false,"path":"/cricket/scores","zone":"www.espn.com.in.cricket","domain":"www.espn.com","loadVidJS":true,"title":"Live Cricket Scores - Find Latest Scores of all Matches Online | ESPN.in","sections":"cricket","authors":"scoreboard"},"qualtrics":false,"nielsen":{"espnuk":{"apid":"P07264C85-15CD-4A80-8E56-B5BFA6D93296","vc":"b01"},"espnau":{"apid":"P07264C85-15CD-4A80-8E56-B5BFA6D93296","vc":"b01"},"espn":{"apid":"P07264C85-15CD-4A80-8E56-B5BFA6D93296","vc":"b01"},"fantasy":{"apid":"P302B69D5-F1DD-4E7A-BF8D-3E60F0EB5E5A","vc":"c07"},"espndeportes":{"apid":"P890E2723-EDBC-4CCE-96BA-F35EA3E50650","vc":"c02"},"espnfc":{"apid":"PE6995AAE-0C49-4372-B5E7-54C61BFE2AA5","vc":"c03"},"espnww":{"apid":"P07264C85-15CD-4A80-8E56-B5BFA6D93296","vc":"b01"},"general":{"ci":"us-600140","assetid":"N/A","segB":"N/A","sfcode":"dcr","segA":"N/A","section":"N/A","segC":"N/A","apn":"espnCOM"},"espnza":{"apid":"P07264C85-15CD-4A80-8E56-B5BFA6D93296","vc":"b01"},"espnin":{"apid":"P07264C85-15CD-4A80-8E56-B5BFA6D93296","vc":"b01"},"watchespn":{"apid":"P07264C85-15CD-4A80-8E56-B5BFA6D93296","vc":"b01"},"cricinfo":{"apid":"PED8CDAC2-F114-41BE-8B98-AFA06FAEA06E","vc":"c04"},"espnbr":{"apid":"P07264C85-15CD-4A80-8E56-B5BFA6D93296","vc":"b01"}},"ABTest":{"environment":"prod","tScript":"https://a.espncdn.com/prod/scripts/analytics/ESPN_at_v2.rs.min.js","oScript":"https://cdn.optimizely.com/js/310987714.js","targetURLs":[{"regexp":"(/)","site":"espn.co.uk","flag":true},{"regexp":"(/.*)","site":"www.espn.com","flag":true}],"domain":"www.espn.com","host":"espn.com","raw":"{\"fastcast\":{\"placements\":{\"/nba/index\":\"true\",\"^/.+$\":\"false\",\"/ncf/index\":\"true\"},\"enabled\":false,\"script\":\"https://a.espncdn.com/combiner/c?js=analytics/espn.fastcastTracking.4.js\"},\"optimizely\":{\"oldscript\":\"https://a.espncdn.com/sports/optimizely.js\",\"placements\":[],\"enabled\":false,\"script\":\"https://cdn.optimizely.com/js/310987714.js\"},\"target\":{\"placements\":[{\"regexp\":\"(/)\",\"site\":\"espn.co.uk\",\"flag\":true},{\"regexp\":\"(/.*)\",\"site\":\"www.espn.com\",\"flag\":true}],\"enabled\":true,\"script\":\"https://a.espncdn.com/prod/scripts/analytics/ESPN_at_v2.rs.min.js\"}}","optimizely":false,"isTargeted":true,"target":true,"optimizelyURLs":[]},"metrics":{"page_url":"/","site":"espnin","content_type":"scoreboard","page_infrastructure":"sCoreNode","page_type":"scoreboard","page_name":"espnin:cricket:scoreboard","section":"cricket","sport":"cricket"},"isFeaturePhone":false,"device":"desktop","cto":false} ]);				}			);
# 		});
# 	}
#
# 	</script>
# <!-- End SiteCatalyst code version: AppMeasurement 1.0 -->
# <script>
#            var espn = espn || {};
#            espn.ads = espn.ads || {};
#            espn.shellParams = espn.shellParams || {};
#            espn.shellParams.excludeTVEProviders = false
#
#
#         </script>
# </body>
# </html>

# %%
def get_dates():
    url = 'https://www.espn.in/cricket/scores'
    sc2 = Scraper(url)
    t=Tag('header',cls='scoreCollection__PageHeader')
    i=Tag('li',cls='DateCarousel__list__item has-event')
    return sc2.get_repeating_date_from_page(
        target=t,
        items=i,
        date=Tag('span',cls='DateCarousel__dayNum'),
        day=Tag('span',cls='DateCarousel__dayName')
    )

# %%
import pandas as pd
Dates=get_dates()
# Create a DataFrame from the list of dates
pd.DataFrame(Dates)
# Out:
#      date  day
# 0  19 Aug  Mon
# 1  20 Aug  Tue
# 2  21 Aug  Wed
# 3  23 Aug  Fri
# 4  24 Aug  Sat
# 5  25 Aug  Sun
# 6  26 Aug  Mon
# 7  27 Aug  Tue

# %%
# def get_scores():
from datetime import datetime
current_date = datetime.strftime(datetime.now(), "%Y%m%d")
# date = '20240801'
url = f'https://www.espn.in/cricket/scores?date={current_date}'
sc1 = Scraper(url)
t = Tag(id='scoreboard-page')
i = Tag(cls='cscore cscore--final cricket cscore--away-winner cscore--watchNotes' )
result = sc1.get_repeating_date_from_page(
      target=t,
      items=i,
      link=Tag('a',cls='scoreEvent__title icon-font-after icon-caret-right-solid-after',output='href'),
      time=Tag('span',cls='cscore_date'),
      date=Tag(cls='cscore_info-overview'),
      home_team = Tag('li', cls='cscore_item cscore_item--home', output='object'),
      away_team = Tag('li', cls='cscore_item cscore_item--away', output='object'),
      result=Tag('span',cls='cscore_notes_game'),
   )
final_result  = []
for item in result:
   home = item['home_team']
   home_score = home.find('div', attrs={'class':'cscore_team icon-font-after'}).find('div', attrs={'class':'cscore_score'}).text
   away = item['away_team']
   away_score = away.find('div', attrs={'class':'cscore_team icon-font-after'}).find('div', attrs={'class':'cscore_score'}).text
   home_team = item['home_team']
   home_team = home.find('div', attrs={'class':'cscore_team icon-font-after'}).find('span', attrs={'class':'cscore_name cscore_name--long'}).text
   away_team = item['away_team']
   away_team = away.find('div', attrs={'class':'cscore_team icon-font-after'}).find('span', attrs={'class':'cscore_name cscore_name--long'}).text
   item['away_score'] =  away_score
   item['home_score'] =  home_score
   item['home_team'] = home_team
   item['away_team'] = away_team
   final_result.append(
      item
   )

# %%
final_result
# Out:
# [{'link': None,
#   'time': 'RESULT',
#   'date': '1st Match,  at Kuala Lumpur, Aug 21 2024',
#   'home_team': 'Hong Kong',
#   'away_team': 'Kuwait',
#   'result': 'Kuwait won by 4 wkts (7b rem)',
#   'away_score': '169/6 (18.5/20 ov, target 169)',
#   'home_score': '168/8'},
#  {'link': None,
#   'time': 'RESULT',
#   'date': '1st Match, Group A,  at Castel, Aug 21 2024',
#   'home_team': 'Cyprus',
#   'away_team': 'Spain',
#   'result': 'Spain won by 15 runs',
#   'away_score': '152/6',
#   'home_score': '137/9 (20 ov, target 153)'},
#  {'link': None,
#   'time': 'RESULT',
#   'date': '3rd Match, Group A,  at Castel, Aug 21 2024',
#   'home_team': 'Czech Republic',
#   'away_team': 'Denmark',
#   'result': 'Denmark won by 118 runs',
#   'away_score': '225/6',
#   'home_score': '107/8 (20 ov, target 226)'},
#  {'link': None,
#   'time': 'RESULT',
#   'date': '19th Match,  at Kabul, Aug 22 2024',
#   'home_team': 'Mis Ainak Knights',
#   'away_team': 'Speen Ghar Tigers',
#   'result': 'SGT won by 5 wkts (19b rem)',
#   'away_score': '130/5 (16.5/20 ov, target 126)',
#   'home_score': '125/9'},
#  {'link': None,
#   'time': 'RESULT',
#   'date': '15th Match,  at Cork, Aug 21 2024',
#   'home_team': 'Munster Reds',
#   'away_team': 'Northern Knights',
#   'result': 'Knights won by 8 wkts (32b rem)',
#   'away_score': '158/2 (14.4/20 ov, target 153)',
#   'home_score': '152'},
#  {'link': None,
#   'time': 'RESULT',
#   'date': '1st Match,  at Marsa, Aug 21 2024',
#   'home_team': 'Malta Women',
#   'away_team': 'Isle of Man Women',
#   'result': 'IOM Women won by 9 wkts (74b rem)',
#   'away_score': '52/1 (7.4/20 ov, target 52)',
#   'home_score': '51'},
#  {'link': None,
#   'time': 'RESULT',
#   'date': 'Qualifier 1,  at Puducherry, Aug 21 2024',
#   'home_team': 'White Town Dropthought Giants',
#   'away_team': 'Mahe Megalo Strikers',
#   'result': 'Mahe won by 7 wkts (2b rem) (DLS)',
#   'away_score': '82/3 (7.4/8 ov, target 79)',
#   'home_score': '71/7 (8/8 ov)'},
#  {'link': None,
#   'time': 'RESULT',
#   'date': '14th Match,  (N) at Bengaluru, Aug 21 2024',
#   'home_team': 'Hubli Tigers',
#   'away_team': 'Mysuru Warriors',
#   'result': 'Mysuru-W won by 56 runs',
#   'away_score': '165',
#   'home_score': '109 (17/20 ov, target 166)'},
#  {'link': None,
#   'time': 'RESULT',
#   'date': '11th Match,  at George Town, Aug 21 2024',
#   'home_team': 'Boca Raton Trailblazers',
#   'away_team': 'New York Strikers',
#   'result': 'Strikers won by 12 runs',
#   'away_score': '115/5',
#   'home_score': '103/7 (10 ov, target 116)'}]

# %%
t = Tag(id='scoreboard-page')
i = Tag(cls='scoreCollection cricket' )
sc1.get_repeating_date_from_page(target=t,items=i,
                                    scorecard_live=Tag('a',cls='cscore_button cscore_button--grouped button--gray button-alt sm react-router-link',output='href'),
                                    summary_report=Tag('a',cls='cscore_button cscore_button--grouped button--gray button-alt sm react-router-link',output='href'),
                                    series_home=Tag('a',cls='cscore_button cscore_button--grouped button--gray button-alt sm',output='href'))
# Out:
# [{'scorecard_live': '/cricket/series/20898/scorecard/1443199/barbados-royals-women-vs-guyana-amazon-warriors-women-1st-match-womens-caribbean-premier-league-2024',
#   'summary_report': '/cricket/series/20898/scorecard/1443199/barbados-royals-women-vs-guyana-amazon-warriors-women-1st-match-womens-caribbean-premier-league-2024',
#   'series_home': '/cricket/series/_/id/20898/season/2024/womens-caribbean-premier-league'},
#  {'scorecard_live': '/cricket/series/22740/game/1442213/pakistan-vs-bangladesh-1st-test-bangladesh-in-pakistan-2024',
#   'summary_report': '/cricket/series/22740/game/1442213/pakistan-vs-bangladesh-1st-test-bangladesh-in-pakistan-2024',
#   'series_home': '/cricket/series/_/id/22740/bangladesh-in-pakistan-2024'},
#  {'scorecard_live': '/cricket/series/21550/game/1385694/england-vs-sri-lanka-1st-test-sri-lanka-in-england-2024',
#   'summary_report': '/cricket/series/21550/game/1385694/england-vs-sri-lanka-1st-test-sri-lanka-in-england-2024',
#   'series_home': '/cricket/series/_/id/21550/sri-lanka-in-england-2024'},
#  {'scorecard_live': '/cricket/series/19439/scorecard/1445039/netherlands-vs-united-states-of-america-24th-match-icc-mens-cricket-world-cup-league-2-2023-24-2027',
#   'summary_report': '/cricket/series/19439/scorecard/1445039/netherlands-vs-united-states-of-america-24th-match-icc-mens-cricket-world-cup-league-2-2023-24-2027',
#   'series_home': '/cricket/series/_/id/19439/season/2024/icc-mens-cricket-world-cup-league-2'},
#  {'scorecard_live': '/cricket/series/18849/scorecard/1444958/samoa-vs-fiji-7th-match-icc-mens-t20-world-cup-east-asia-pacific-region-qualifier-a-2024',
#   'summary_report': '/cricket/series/18849/scorecard/1444958/samoa-vs-fiji-7th-match-icc-mens-t20-world-cup-east-asia-pacific-region-qualifier-a-2024',
#   'series_home': '/cricket/series/_/id/18849/season/2024/icc-mens-t20-world-cup-east-asia-pacific-region-qualifier-a'},
#  {'scorecard_live': '/cricket/series/19301/scorecard/1446771/hong-kong-vs-kuwait-1st-match-malaysia-tri-nation-t20i-series-2024',
#   'summary_report': '/cricket/series/19301/scorecard/1446771/hong-kong-vs-kuwait-1st-match-malaysia-tri-nation-t20i-series-2024',
#   'series_home': '/cricket/series/_/id/19301/season/2024/malaysia-tri-nation-t20i-series'},
#  {'scorecard_live': '/cricket/series/20855/scorecard/1443766/cyprus-vs-spain-1st-match-group-a-icc-mens-t20-world-cup-sub-regional-europe-qualifier-group-c-2024',
#   'summary_report': '/cricket/series/20855/scorecard/1443766/cyprus-vs-spain-1st-match-group-a-icc-mens-t20-world-cup-sub-regional-europe-qualifier-group-c-2024',
#   'series_home': '/cricket/series/_/id/20855/season/2024/icc-mens-t20-world-cup-sub-regional-europe-qualifier-group-c'},
#  {'scorecard_live': '/cricket/series/18041/scorecard/1446809/boost-defenders-vs-mis-ainak-knights-17th-match-shpageeza-cricket-league-2024',
#   'summary_report': '/cricket/series/18041/scorecard/1446809/boost-defenders-vs-mis-ainak-knights-17th-match-shpageeza-cricket-league-2024',
#   'series_home': '/cricket/series/_/id/18041/season/2024/shpageeza-cricket-league'},
#  {'scorecard_live': '/cricket/series/11084/scorecard/1430842/munster-reds-vs-northern-knights-15th-match-cricket-ireland-inter-provincial-twenty20-trophy-2024',
#   'summary_report': '/cricket/series/11084/scorecard/1430842/munster-reds-vs-northern-knights-15th-match-cricket-ireland-inter-provincial-twenty20-trophy-2024',
#   'series_home': '/cricket/series/_/id/11084/season/2024/cricket-ireland-inter-provincial-twenty20-trophy'},
#  {'scorecard_live': '/cricket/series/1447532/scorecard/1447543/malta-women-vs-isle-of-man-women-1st-match-womens-valletta-cup-2024',
#   'summary_report': '/cricket/series/1447532/scorecard/1447543/malta-women-vs-isle-of-man-women-1st-match-womens-valletta-cup-2024',
#   'series_home': '/cricket/series/_/id/1447532/season/2024/womens-valletta-cup'},
#  {'scorecard_live': '/cricket/series/8204/game/1410299/derbyshire-vs-glamorgan-37th-match-county-championship-division-two-2024',
#   'summary_report': '/cricket/series/8204/game/1410299/derbyshire-vs-glamorgan-37th-match-county-championship-division-two-2024',
#   'series_home': '/cricket/series/_/id/8204/season/2024/county-championship-division-two'},
#  {'scorecard_live': '/cricket/series/8052/game/1410238/durham-vs-nottinghamshire-46th-match-county-championship-division-one-2024',
#   'summary_report': '/cricket/series/8052/game/1410238/durham-vs-nottinghamshire-46th-match-county-championship-division-one-2024',
#   'series_home': '/cricket/series/_/id/8052/season/2024/county-championship-division-one'},
#  {'scorecard_live': '/cricket/series/1445452/game/1445459/pakistan-a-vs-bangladesh-a-2nd-unofficial-test-',
#   'summary_report': '/cricket/series/1445452/game/1445459/pakistan-a-vs-bangladesh-a-2nd-unofficial-test-',
#   'series_home': '/cricket/series/_/id/1445452/'},
#  {'scorecard_live': '/cricket/series/11083/game/1429577/munster-reds-vs-northern-knights-9th-match-cricket-ireland-inter-provincial-limited-over-cup-2024',
#   'summary_report': '/cricket/series/11083/game/1429577/munster-reds-vs-northern-knights-9th-match-cricket-ireland-inter-provincial-limited-over-cup-2024',
#   'series_home': '/cricket/series/_/id/11083/season/2024/cricket-ireland-inter-provincial-limited-over-cup'},
#  {'scorecard_live': '/cricket/series/1443790/game/1443800/australia-a-women-vs-india-a-women-only-unofficial-test-',
#   'summary_report': '/cricket/series/1443790/game/1443800/australia-a-women-vs-india-a-women-only-unofficial-test-',
#   'series_home': '/cricket/series/_/id/1443790/'},
#  {'scorecard_live': '/cricket/series/1445031/scorecard/1446399/white-town-dropthought-giants-vs-mahe-megalo-strikers-qualifier-1-pondicherry-premier-league-2024',
#   'summary_report': '/cricket/series/1445031/scorecard/1446399/white-town-dropthought-giants-vs-mahe-megalo-strikers-qualifier-1-pondicherry-premier-league-2024',
#   'series_home': '/cricket/series/_/id/1445031/season/2024/pondicherry-premier-league'},
#  {'scorecard_live': '/cricket/series/22014/scorecard/1447511/gulbarga-mystics-vs-shivamogga-lions-13th-match-maharaja-t20-trophy-2024',
#   'summary_report': '/cricket/series/22014/scorecard/1447511/gulbarga-mystics-vs-shivamogga-lions-13th-match-maharaja-t20-trophy-2024',
#   'series_home': '/cricket/series/_/id/22014/season/2024/maharaja-t20-trophy'},
#  {'scorecard_live': '/cricket/series/8859/game/1428241/glamorgan-2nd-xi-vs-leicestershire-2nd-xi-50th-match-second-eleven-championship-2024',
#   'summary_report': '/cricket/series/8859/game/1428241/glamorgan-2nd-xi-vs-leicestershire-2nd-xi-50th-match-second-eleven-championship-2024',
#   'series_home': '/cricket/series/_/id/8859/season/2024/second-eleven-championship'},
#  {'scorecard_live': '/cricket/series/1448167/scorecard/1448184/caribbean-tigers-vs-miami-lions-10th-match-max60-caribbean-2024',
#   'summary_report': '/cricket/series/1448167/scorecard/1448184/caribbean-tigers-vs-miami-lions-10th-match-max60-caribbean-2024',
#   'series_home': '/cricket/series/_/id/1448167/season/2024/max60-caribbean'}]

# %%
#ICC ODI RANKING
url='https://www.espncricinfo.com/rankings/icc-team-ranking'
sc3=Scraper(url)
t=Tag('tbody')
i=Tag('tr')
sc3.get_repeating_date_from_page(
    target=t,
    items=i,
    position=Tag('td',cls='ds-min-w-max'),
    team=Tag('a',cls='ds-inline-flex ds-items-start ds-leading-none',output='href'),
    matches=Tag('td',cls='ds-min-w-max'),
    points=Tag('td',
    cls='ds-min-w-max'),
    rating=Tag('td',cls='ds-min-w-max')
    )
# Out:
# [{'position': '1',
#   'team': '/team/india-6',
#   'matches': '1',
#   'points': '1',
#   'rating': '1'},
#  {'position': '2',
#   'team': '/team/australia-2',
#   'matches': '2',
#   'points': '2',
#   'rating': '2'},
#  {'position': '3',
#   'team': '/team/south-africa-3',
#   'matches': '3',
#   'points': '3',
#   'rating': '3'},
#  {'position': '4',
#   'team': '/team/pakistan-7',
#   'matches': '4',
#   'points': '4',
#   'rating': '4'},
#  {'position': '5',
#   'team': '/team/new-zealand-5',
#   'matches': '5',
#   'points': '5',
#   'rating': '5'},
#  {'position': '6',
#   'team': '/team/sri-lanka-8',
#   'matches': '6',
#   'points': '6',
#   'rating': '6'},
#  {'position': '7',
#   'team': '/team/england-1',
#   'matches': '7',
#   'points': '7',
#   'rating': '7'},
#  {'position': '8',
#   'team': '/team/bangladesh-25',
#   'matches': '8',
#   'points': '8',
#   'rating': '8'},
#  {'position': '9',
#   'team': '/team/afghanistan-40',
#   'matches': '9',
#   'points': '9',
#   'rating': '9'},
#  {'position': '10',
#   'team': '/team/west-indies-4',
#   'matches': '10',
#   'points': '10',
#   'rating': '10'},
#  {'position': '11',
#   'team': '/team/scotland-30',
#   'matches': '11',
#   'points': '11',
#   'rating': '11'},
#  {'position': '12',
#   'team': '/team/ireland-29',
#   'matches': '12',
#   'points': '12',
#   'rating': '12'},
#  {'position': '13',
#   'team': '/team/zimbabwe-9',
#   'matches': '13',
#   'points': '13',
#   'rating': '13'},
#  {'position': '14',
#   'team': '/team/netherlands-15',
#   'matches': '14',
#   'points': '14',
#   'rating': '14'},
#  {'position': '15',
#   'team': '/team/namibia-28',
#   'matches': '15',
#   'points': '15',
#   'rating': '15'},
#  {'position': '16',
#   'team': '/team/nepal-33',
#   'matches': '16',
#   'points': '16',
#   'rating': '16'},
#  {'position': '17',
#   'team': '/team/oman-37',
#   'matches': '17',
#   'points': '17',
#   'rating': '17'},
#  {'position': '18',
#   'team': '/team/united-states-of-america-11',
#   'matches': '18',
#   'points': '18',
#   'rating': '18'},
#  {'position': '19',
#   'team': '/team/canada-17',
#   'matches': '19',
#   'points': '19',
#   'rating': '19'},
#  {'position': '20',
#   'team': '/team/united-arab-emirates-27',
#   'matches': '20',
#   'points': '20',
#   'rating': '20'}]

# %%
#ICC T20I RANKING
url='https://www.espncricinfo.com/rankings/icc-team-ranking'
sc3=Scraper(url)
t=Tag('tbody')
i=Tag('tr')
sc3.get_repeating_date_from_page(target=t,items=i,
                                 position=Tag('td',cls='ds-min-w-max'),
                                 team=Tag('a',cls='ds-inline-flex ds-items-start ds-leading-none',output='href'),
                                 team_logo=Tag('img',output='src'),
                                 matches=Tag('td',cls='ds-min-w-max'),
                                 points=Tag('td',
                                 cls='ds-min-w-max'),
                                 rating=Tag('td',cls='ds-min-w-max'))
# Out:
# [{'position': '1',
#   'team': '/team/india-6',
#   'team_logo': 'https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_160,q_50/lsci/db/PICTURES/CMS/381800/381895.png',
#   'matches': '1',
#   'points': '1',
#   'rating': '1'},
#  {'position': '2',
#   'team': '/team/australia-2',
#   'team_logo': 'https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_160,q_50/lsci/db/PICTURES/CMS/340400/340493.png',
#   'matches': '2',
#   'points': '2',
#   'rating': '2'},
#  {'position': '3',
#   'team': '/team/south-africa-3',
#   'team_logo': 'https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_160,q_50/lsci/db/PICTURES/CMS/382700/382733.png',
#   'matches': '3',
#   'points': '3',
#   'rating': '3'},
#  {'position': '4',
#   'team': '/team/pakistan-7',
#   'team_logo': 'https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_160,q_50/lsci/db/PICTURES/CMS/381800/381891.png',
#   'matches': '4',
#   'points': '4',
#   'rating': '4'},
#  {'position': '5',
#   'team': '/team/new-zealand-5',
#   'team_logo': 'https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_160,q_50/lsci/db/PICTURES/CMS/340500/340505.png',
#   'matches': '5',
#   'points': '5',
#   'rating': '5'},
#  {'position': '6',
#   'team': '/team/sri-lanka-8',
#   'team_logo': 'https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_160,q_50/lsci/db/PICTURES/CMS/340000/340047.png',
#   'matches': '6',
#   'points': '6',
#   'rating': '6'},
#  {'position': '7',
#   'team': '/team/england-1',
#   'team_logo': 'https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_160,q_50/lsci/db/PICTURES/CMS/381800/381894.png',
#   'matches': '7',
#   'points': '7',
#   'rating': '7'},
#  {'position': '8',
#   'team': '/team/bangladesh-25',
#   'team_logo': 'https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_160,q_50/lsci/db/PICTURES/CMS/341400/341456.png',
#   'matches': '8',
#   'points': '8',
#   'rating': '8'},
#  {'position': '9',
#   'team': '/team/afghanistan-40',
#   'team_logo': 'https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_160,q_50/lsci/db/PICTURES/CMS/381800/381892.png',
#   'matches': '9',
#   'points': '9',
#   'rating': '9'},
#  {'position': '10',
#   'team': '/team/west-indies-4',
#   'team_logo': 'https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_160,q_50/lsci/db/PICTURES/CMS/317600/317615.png',
#   'matches': '10',
#   'points': '10',
#   'rating': '10'},
#  {'position': '11',
#   'team': '/team/scotland-30',
#   'team_logo': 'https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_160,q_50/lsci/db/PICTURES/CMS/313100/313150.logo.png',
#   'matches': '11',
#   'points': '11',
#   'rating': '11'},
#  {'position': '12',
#   'team': '/team/ireland-29',
#   'team_logo': 'https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_160,q_50/lsci/db/PICTURES/CMS/313100/313149.logo.png',
#   'matches': '12',
#   'points': '12',
#   'rating': '12'},
#  {'position': '13',
#   'team': '/team/zimbabwe-9',
#   'team_logo': 'https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_160,q_50/lsci/db/PICTURES/CMS/340500/340503.png',
#   'matches': '13',
#   'points': '13',
#   'rating': '13'},
#  {'position': '14',
#   'team': '/team/netherlands-15',
#   'team_logo': 'https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_160,q_50/lsci/db/PICTURES/CMS/381800/381893.png',
#   'matches': '14',
#   'points': '14',
#   'rating': '14'},
#  {'position': '15',
#   'team': '/team/namibia-28',
#   'team_logo': 'https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_160,q_50/lsci/db/PICTURES/CMS/381800/381857.png',
#   'matches': '15',
#   'points': '15',
#   'rating': '15'},
#  {'position': '16',
#   'team': '/team/nepal-33',
#   'team_logo': 'https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_160,q_50/lsci/db/PICTURES/CMS/319900/319958.png',
#   'matches': '16',
#   'points': '16',
#   'rating': '16'},
#  {'position': '17',
#   'team': '/team/united-states-of-america-11',
#   'team_logo': 'https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_160,q_50/lsci/db/PICTURES/CMS/381800/381853.png',
#   'matches': '17',
#   'points': '17',
#   'rating': '17'},
#  {'position': '18',
#   'team': '/team/oman-37',
#   'team_logo': 'https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_160,q_50/lsci/db/PICTURES/CMS/381800/381858.png',
#   'matches': '18',
#   'points': '18',
#   'rating': '18'},
#  {'position': '19',
#   'team': '/team/canada-17',
#   'team_logo': 'https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_160,q_50/lsci/db/PICTURES/CMS/381800/381855.png',
#   'matches': '19',
#   'points': '19',
#   'rating': '19'},
#  {'position': '20',
#   'team': '/team/united-arab-emirates-27',
#   'team_logo': 'https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_160,q_50/lsci/db/PICTURES/CMS/382100/382186.png',
#   'matches': '20',
#   'points': '20',
#   'rating': '20'}]
