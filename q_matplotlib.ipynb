# %% [markdown]
# tasks for generating different types of plots using the Iris dataset, pandas, and Matplotlib:
# Scatter Plot with Different Colors: Task: Create a scatter plot of sepal length against sepal width for the Iris dataset. Use different colors for each species to distinguish them. Customize the plot with appropriate labels and a legend.
#
# Histogram for Feature Distribution: Task: Generate a histogram to visualize the distribution of petal length for all samples in the Iris dataset. Customize the plot with appropriate labels and adjust the number of bins to display the data effectively.
#
# Box Plot Comparison: Task: Create a box plot to compare the sepal width distributions for each species in the Iris dataset. Customize the plot by assigning different colors to each species, adding appropriate labels, and adjusting the style of the box plot (e.g., adding outliers, changing whisker styles).
#
# Line Plot with Multiple Lines: Task: Generate a line plot to compare the variations of sepal length and petal length across the samples in the Iris dataset. Each line represents a different species. Customize the plot by adding appropriate labels and a legend.
#
# Bar Chart for Categorical Data: Task: Create a bar chart to display the frequency of each species in the Iris dataset. Customize the plot with appropriate labels, a title, and different colors for each species.

# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
iris = sns.load_dataset('iris')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# Scatter Plot with Different Colors: Task: Create a scatter plot of sepal length against sepal width for the Iris dataset. Use different colors for each species to distinguish them. Customize the plot with appropriate labels and a legend.

# %%
sns.scatterplot(x='sepal_length',
            y='sepal_width',
            data=iris,
            hue='species')
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
setosa = iris[iris['species'] == 'setosa']
versicolor = iris[iris['species'] == 'versicolor']
virginica = iris[iris['species'] == 'virginica']

# %%
plt.figure(figsize=(8,5))
plt.scatter(x='sepal_length',
            y='sepal_width',
            data=setosa,
            color='#1E6EA7',
            label = 'Setosa')
plt.scatter(x='sepal_length',
            y='sepal_width',
            data=versicolor,
            color='green',
            label = 'Versicolor')
plt.scatter(x='sepal_length',
            y='sepal_width',
            data=virginica,
            color='#F1AD2E',
            label = 'Virginica')
plt.xlabel('Sepal length')
plt.ylabel('Sepal width')
plt.legend(title = 'species')

# %% [markdown]
# Histogram for Feature Distribution: Task: Generate a histogram to visualize the distribution of petal length for all samples in the Iris dataset. Customize the plot with appropriate labels and adjust the number of bins to display the data effectively.

# %%
x = iris['petal_length']
plt.hist(x,bins=50,color='skyblue',edgecolor='black')
plt.title('Distribution of Petal Length in Iris Dataset')
plt.xlabel('Petal Length (cm)')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
sns.histplot(data=iris,
             x='petal_length',
             kde=True,
             bins=50)
# Out:
# <Axes: xlabel='petal_length', ylabel='Count'>

# %% [markdown]
# Box Plot Comparison: Task: Create a box plot to compare the sepal width distributions for each species in the Iris dataset. Customize the plot by assigning different colors to each species, adding appropriate labels, and adjusting the style of the box plot (e.g., adding outliers, changing whisker styles).

# %%
sns.boxplot(x='species',y = 'sepal_width',data=iris,hue='species')
# Out:
# <Axes: xlabel='species', ylabel='sepal_width'>

# %% [markdown]
# Line Plot with Multiple Lines: Task: Generate a line plot to compare the variations of sepal length and petal length across the samples in the Iris dataset. Each line represents a different species. Customize the plot by adding appropriate labels and a legend.

# %%
import pandas as pd

# %%
sns.lineplot(data=iris,x='sepal_length',y='petal_length',hue='species')
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
# Create a DataFrame for easier manipulation
iris_df = pd.DataFrame(data=iris)

# Separate data by species
setosa = iris_df[iris_df['species'] == 'setosa']
versicolor = iris_df[iris_df['species'] == 'versicolor']
virginica = iris_df[iris_df['species'] == 'virginica']

# %%
# Create a line plot
plt.figure(figsize=(20, 6))

# Plot sepal length and petal length for each species
plt.plot(setosa.index, setosa['sepal_length'], color='blue', linestyle='-', marker='o', label='Setosa - Sepal Length')
plt.plot(setosa.index, setosa['petal_length'], color='blue', linestyle='--', marker='x', label='Setosa - Petal Length')

plt.plot(versicolor.index, versicolor['sepal_length'], color='green', linestyle='-', marker='o', label='Versicolor - Sepal Length')
plt.plot(versicolor.index, versicolor['petal_length'], color='green', linestyle='--', marker='x', label='Versicolor - Petal Length')

plt.plot(virginica.index, virginica['sepal_length'], color='red', linestyle='-', marker='o', label='Virginica - Sepal Length')
plt.plot(virginica.index, virginica['petal_length'], color='red', linestyle='--', marker='x', label='Virginica - Petal Length')

# Adding labels and title
plt.title('Comparison of Sepal Length and Petal Length Across Iris Species')
plt.xlabel('Sample Index')
plt.ylabel('Length (cm)')

# Adding a legend
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# Bar Chart for Categorical Data: Task: Create a bar chart to display the frequency of each species in the Iris dataset. Customize the plot with appropriate labels, a title, and different colors for each species.

# %%
plt.figure(figsize=(7,5))
y= iris['species'].value_counts()
x = ['setosa','virginica','versicolor']
plt.bar(x,y,color=['#1E6EA7', 'green', '#e68a00'])
plt.ylabel("Frequency")
plt.xlabel("Species")
plt.title('Frequency of Each Species in the Iris Dataset')
plt.show()

# %%
sns.countplot(data=iris,x='species',hue='species')
# Out:
# <Axes: xlabel='species', ylabel='count'>
